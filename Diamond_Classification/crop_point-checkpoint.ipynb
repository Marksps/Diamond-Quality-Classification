# %% [markdown]
# # Test Point

# %%
import numpy as np
import cv2
import cv2 as cv
from matplotlib import image 
from matplotlib import pyplot as plt

# %%
def point_com(img):
    point_lst = []
    gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
    corners = cv2.goodFeaturesToTrack(gray,9000,0.01,8)
    ##corners = cv2.goodFeaturesToTrack(gray,3,0.01,10)
    corners = np.int0(corners)
    for i in corners:
        x,y = i.ravel()
        cv2.circle(img,(x,y),3,255,-1)
        point_lst.append((x,y))
    plt.imshow(img),plt.show()
    #plt.imshow(img),plt.grid(b=True, which='both', color='w', linestyle='--'),plt.show()
    return point_lst

# %%
link = ('a.jpg')
img = cv2.imread(link)
p = point_com(img)
print(p)
# Out:
# [(356, 66), (3, 212), (58, 68), (3, 226), (349, 59), (67, 58), (57, 346), (212, 3), (412, 190), (210, 412), (277, 359), (396, 127), (280, 57), (19, 288), (66, 356), (21, 123), (365, 153), (3, 187), (413, 205), (132, 56), (48, 260), (357, 136), (55, 279), (277, 400), (227, 3), (282, 17), (366, 77), (3, 199), (13, 187), (198, 411), (328, 59), (17, 226), (130, 397), (354, 350), (290, 20), (28, 142), (85, 58), (356, 86), (152, 49), (56, 132), (183, 397), (48, 336), (223, 411), (338, 49), (182, 411), (223, 399), (58, 87), (87, 355), (412, 214), (262, 50), (285, 396), (49, 77), (386, 291), (356, 283), (227, 17), (77, 365), (150, 365), (400, 191), (76, 50), (16, 279), (322, 358), (365, 263), (383, 273), (48, 151), (371, 278), (186, 17), (131, 18), (130, 357), (395, 231), (289, 35), (187, 3), (138, 42), (354, 326), (385, 146), (365, 338), (146, 35), (57, 329), (257, 368), (272, 374), (276, 45), (374, 129), (124, 377), (40, 286), (200, 3), (283, 377), (140, 14), (376, 290), (42, 274), (411, 2
# ...

# %%
link = ('a-50-3.png')
img = cv2.imread(link)
p = point_com(img)
print(p)
# Out:
# [(2, 208), (175, 210), (165, 230), (165, 190), (19, 203), (36, 199), (57, 194), (10, 205), (35, 219), (27, 201), (75, 194), (91, 213), (60, 226), (47, 222), (138, 226), (47, 196), (70, 229), (19, 214), (98, 229), (98, 196), (137, 191), (108, 202), (78, 229), (125, 200), (42, 215), (117, 191), (169, 222), (170, 200), (83, 219), (119, 225), (85, 201), (95, 220), (107, 191), (150, 229)]

# %% [markdown]
# # Crop Arrow complete

# %%
def cut_a_1(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_1 = np.array([[(207,0),(183,60),(183,160),(207,175),(230,160),(230,60)]], dtype=np.int32)    
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_1, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/com-a-'+ str(i) +'-1.png', masked_image) 
def cut_a_2(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_2 = np.array([[(60,60),(85,120),(155,190),(180,185),(190,155),(120,85)]], dtype=np.int32)    
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_2, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/com-a-'+ str(i) +'-2.png', masked_image)
def cut_a_3(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_3 = np.array([[(0,205),(60,183),(160,183),(175,205),(160,230),(60,230)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_3, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/com-a-'+ str(i) +'-3.png', masked_image) 
def cut_a_4(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_4 = np.array([[(55,355),(125,318),(190,260),(185,230),(155,225),(90,285)]], dtype=np.int32)     
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_4, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/com-a-'+ str(i) +'-4.png', masked_image) 

def cut_a_5(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_5 = np.array([[(205,415),(230,350),(230,250),(205,240),(180,250),(180,350)]], dtype=np.int32)     
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_5, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/com-a-'+ str(i) +'-5.png', masked_image) 
def cut_a_6(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_6 = np.array([[(356,354),(330,290),(260,220),(228,225),(220,255),(290,325)]], dtype=np.int32)     
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_6, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/com-a-'+ str(i) +'-6.png', masked_image) 
def cut_a_7(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_7 = np.array([[(415,205),(350,230),(250,230),(240,205),(250,180),(350,180)]], dtype=np.int32)     
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_7, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/com-a-'+ str(i) +'-7.png', masked_image) 
def cut_a_8(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_8 = np.array([[(353,60),(285,95),(220,160),(227,190),(260,190),(320,130)]], dtype=np.int32)     
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_8, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/com-a-'+ str(i) +'-8.png', masked_image)

# %%
for i in range(1,474):
    link = ('com-a-'+ str(i) +'.PNG')
    img = cv2.imread(link)
    cut_a_1(img)
    cut_a_2(img)
    cut_a_3(img)
    cut_a_4(img)
    cut_a_5(img)
    cut_a_6(img)
    cut_a_7(img)
    cut_a_8(img)

# %% [markdown]
# # Crop Arrow incomplete

# %%
def cut_a_1(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    #                             1        2        3         4         5         6
    roi_corners_1 = np.array([[(207,0),(183,60),(183,160),(207,175),(230,160),(230,60)]], dtype=np.int32)    
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_1, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/inc-a-'+ str(i) +'-1.png', masked_image) 
def cut_a_2(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_2 = np.array([[(60,60),(85,120),(155,190),(180,185),(190,155),(120,85)]], dtype=np.int32)    
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_2, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/inc-a-'+ str(i) +'-2.png', masked_image)
def cut_a_3(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_3 = np.array([[(0,205),(60,183),(160,183),(175,205),(160,230),(60,230)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_3, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/inc-a-'+ str(i) +'-3.png', masked_image) 
def cut_a_4(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_4 = np.array([[(55,355),(125,318),(190,260),(185,230),(155,225),(90,285)]], dtype=np.int32)     
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_4, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/inc-a-'+ str(i) +'-4.png', masked_image) 

def cut_a_5(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_5 = np.array([[(205,415),(230,350),(230,250),(205,240),(180,250),(180,350)]], dtype=np.int32)     
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_5, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/inc-a-'+ str(i) +'-5.png', masked_image) 
def cut_a_6(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_6 = np.array([[(356,354),(330,290),(260,220),(228,225),(220,255),(290,325)]], dtype=np.int32)     
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_6, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/inc-a-'+ str(i) +'-6.png', masked_image) 
def cut_a_7(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_7 = np.array([[(415,205),(350,230),(250,230),(240,205),(250,180),(350,180)]], dtype=np.int32)     
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_7, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/inc-a-'+ str(i) +'-7.png', masked_image) 
def cut_a_8(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_8 = np.array([[(353,60),(285,95),(220,160),(227,190),(260,190),(320,130)]], dtype=np.int32)     
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_8, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/inc-a-'+ str(i) +'-8.png', masked_image)

# %%
for i in range(1,732):
    link = ('inc-a-'+ str(i) +'.PNG')
    img = cv2.imread(link)
    cut_a_1(img)
    cut_a_2(img)
    cut_a_3(img)
    cut_a_4(img)
    cut_a_5(img)
    cut_a_6(img)
    cut_a_7(img)
    cut_a_8(img)

# %% [markdown]
# ---------------------------------------------------------------------------

# %% [markdown]
# # Crop Hart complete

# %%
def cut_h_1(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_1 = np.array([[(95,70), (205,205), (195,30)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_1, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/com-h-'+ str(i) +'-1.png', masked_image)
    
def cut_h_2(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_2 = np.array([[(70,95), (205,205), (30,190)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_2, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/com-h-'+ str(i) +'-2.png', masked_image)
    
def cut_h_3(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_3 = np.array([[(30,225), (205,205), (70,320)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_3, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/com-h-'+ str(i) +'-3.png', masked_image) 
    
def cut_h_4(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_4 = np.array([[(100,345), (210,190), (190,385)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_4, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/com-h-'+ str(i) +'-4.png', masked_image) 
    
def cut_h_5(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_5 = np.array([[(220,385), (205,205), (320,345)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_5, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/com-h-'+ str(i) +'-5.png', masked_image) 
    
def cut_h_6(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_6 = np.array([[(345,320), (205,205), (385,220)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_6, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/com-h-'+ str(i) +'-6.png', masked_image)
    
def cut_h_7(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_7 = np.array([[(345,95), (205,205), (385,190)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_7, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/com-h-'+ str(i) +'-7.png', masked_image) 
    
def cut_h_8(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_8 = np.array([[(220,30), (205,205), (320,70)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_8, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/com-h-'+ str(i) +'-8.png', masked_image)

# %%
for i in range(1,620):
    link = ('com-h-'+ str(i) +'.PNG')
    img = cv2.imread(link)
    cut_h_1(img)
    cut_h_2(img)
    cut_h_3(img)
    cut_h_4(img)
    cut_h_5(img)
    cut_h_6(img)
    cut_h_7(img)
    cut_h_8(img)

# %% [markdown]
# # Crop Hart Incomplete

# %%
def cut_h_1(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_1 = np.array([[(95,70), (205,205), (195,30)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_1, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/inc-h-'+ str(i) +'-1.png', masked_image)
    
def cut_h_2(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_2 = np.array([[(60,80), (205,210), (15,190)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_2, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/inc-h-'+ str(i) +'-2.png', masked_image)
    
def cut_h_3(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_3 = np.array([[(15,220), (205,210), (60,330)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_3, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/inc-h-'+ str(i) +'-3.png', masked_image) 
    
def cut_h_4(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_4 = np.array([[(70,350), (205,210), (190,400)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_4, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/inc-h-'+ str(i) +'-4.png', masked_image) 
    
def cut_h_5(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_5 = np.array([[(210,400), (205,205), (330,350)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_5, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/inc-h-'+ str(i) +'-5.png', masked_image) 
    
def cut_h_6(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_6 = np.array([[(350,330), (200,205), (390,210)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_6, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/inc-h-'+ str(i) +'-6.png', masked_image)
    
def cut_h_7(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_7 = np.array([[(350,80), (200,205), (390,190)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_7, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/inc-h-'+ str(i) +'-7.png', masked_image) 
    
def cut_h_8(image):
    #resize image
    width = 416
    height = 414
    dim = (width, height)
    image = cv2.resize(image, dim)
    roi_corners_8 = np.array([[(210,20), (205,205), (330,60)]], dtype=np.int32)
    # crop image
    mask = np.zeros(image.shape, dtype=np.uint8)
    channel_count = image.shape[2]
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners_8, ignore_mask_color)
    masked_image = cv2.bitwise_and(image, mask)
    cv2.imwrite('cut/inc-h-'+ str(i) +'-8.png', masked_image)

# %%
for i in range(1,620):
    link = ('inc-h-'+ str(i) +'.PNG')
    img = cv2.imread(link)
    cut_h_1(img)
    cut_h_2(img)
    cut_h_3(img)
    cut_h_4(img)
    cut_h_5(img)
    cut_h_6(img)
    cut_h_7(img)
    cut_h_8(img)

# %% [markdown]
# # point

# %%
# importing the module
import cv2
   
# function to display the coordinates of
# of the points clicked on the image 
def click_event(event, x, y, flags, params):
    
    list_point = []
    # checking for left mouse clicks
    if event == cv2.EVENT_LBUTTONDOWN:
  
        # displaying the coordinates
        # on the Shell
        list_point.append((x,y))
        print((x,y))

        # displaying the coordinates
        # on the image window
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(img, str(x) + ',' +
                    str(y), (x,y), font,
                    0.001, (255, 0, 0), 2)
        cv2.imshow('image', img)
  
    # checking for right mouse clicks     
    if event==cv2.EVENT_RBUTTONDOWN:
  
        # displaying the coordinates
        # on the Shell
        print((x,y))
  
        # displaying the coordinates
        # on the image window
        font = cv2.FONT_HERSHEY_SIMPLEX
        b = img[y, x, 0]
        g = img[y, x, 1]
        r = img[y, x, 2]
        cv2.putText(img, str(b) + ',' +
                    str(g) + ',' + str(r),
                    (x,y), font, 0.001,
                    (255, 255, 0), 2)
        cv2.imshow('image', img)
    return list_point
  
# driver function
if __name__=="__main__":
  
    # reading the image
                    # 1 2 3 4 5 6 7 8 9 0
    img = cv2.imread('cut/inc-a-120-5.PNG')
  
    # displaying the image
    cv2.imshow('image', img)
  
    # setting mouse hadler for the image
    # and calling the click_event() function
    cv2.setMouseCallback('image', click_event)
  
    # wait for a key to be pressed to exit
    cv2.waitKey(0)
  
    # close the window
    cv2.destroyAllWindows()
# Out:
# (207, 408)
# (221, 343)
# (214, 326)
# (205, 319)
# (194, 327)
# (190, 344)
# (213, 313)
# (207, 316)
# (200, 314)
# (188, 254)
# (204, 245)
# (220, 256)

# %% [markdown]
# ----------------------------------

# %% [markdown]
# ## code เก่า

# %%
#####อันเก่า
def point(img):
    point_lst = []
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    corners = cv2.goodFeaturesToTrack(gray,15,0.10,9)
    corners = np.int0(corners)
    for i in corners:
        x,y = i.ravel()
        cv2.circle(img,(x,y),3,255,-1)
        point_lst.append((x,y))
    plt.imshow(img),plt.grid(b=True, which='both', color='w', linestyle='--'),plt.show()

    return point_lst

# %%
#ส่วนที่ 1

result_list = []

lists = (193, 67),
(224, 66),
(198, 99),
(211, 93),
(222, 156),
(207, 165)
num1,num2,num3,num4,num5,num6,num7,num8,num9,num10,num11,num12 = (),(),(),(),(),(),(),(),(),(),(),()

for i in lists:
    if 205 <= i[0] <= 215 and 0 <= i[1] <= 10 :
        num1 = i
        
    if 190 <= i[0] <= 195 and 65 <= i[1] <= 75 :
        num2 = i
        
    if 195 <= i[0] <= 205 and 65 <= i[1] <= 85 :
        num3 = i
        
    if 205 <= i[0] <= 210 and 81 <= i[1] <= 90 :
        num4 = i
        
    if 210 <= i[0] <= 215 and 80 <= i[1] <= 90 :
        num5 = i
        
    if 220 <= i[0] <= 225 and 60 <= i[1] <= 70 :
        num6 = i
        
    if 196 <= i[0] <= 205 and 85 <= i[1] <= 99 :
        num7 = i
        
    if 205 <= i[0] <= 210 and  90 <= i[1] <= 95 :
        num8 = i
        
    if 205 <= i[0] <= 215 and  85 <= i[1] <= 98 :
        num9 = i
        
    if 220 <= i[0] <= 225 and 145 <= i[1] <= 165 :
        num10 = i
    
    if 205 <= i[0] <= 210 and 150 <= i[1] <= 175 :
        num11 = i
        
    if 190 <= i[0] <= 195 and 145 <= i[1] <= 165 :
        num12 = i


result_list.append(num1)
result_list.append(num2)
result_list.append(num3)
result_list.append(num4)
result_list.append(num5)
result_list.append(num6)
result_list.append(num7)
result_list.append(num8)
result_list.append(num9)
result_list.append(num10)
result_list.append(num11)
result_list.append(num12)

# %%
for i in range(1):
    for j in range(2,3):
        list_p_1 = []
        link = ('cut/com-h-24-'+str(j+1)+'.png')
        img = cv2.imread(link)
        p = point(img)
        list_p_1.append(p)
        print(list_p_1)
# Out:
# [[(44, 256), (55, 283), (49, 269), (164, 221), (149, 228), (81, 257), (197, 208), (46, 235), (79, 220)]]

# %%
for i in range(70,120):
    for j in range(2):
        link = ('cut/inc-h-'+str(i+1)+'-'+str(j+1)+'.png')
        img = cv2.imread(link)
        p = point_inc(img)
        print(p)
# Out:
# [(187, 157), (149, 117), (153, 117), (166, 50), (184, 149), (167, 48), (190, 101), (201, 190), (111, 64), (154, 124), (160, 122), (178, 45), (135, 59), (156, 125), (200, 187), (114, 62), (155, 78), (154, 46), (140, 113), (133, 112), (205, 205), (139, 52), (151, 48), (164, 48), (161, 138), (141, 54), (164, 122), (144, 50), (183, 95), (146, 50), (194, 35), (186, 94), (195, 30), (187, 99), (136, 54), (193, 123), (179, 36), (119, 60), (121, 59), (161, 44), (176, 146), (176, 38), (128, 64), (166, 143), (124, 58), (188, 138), (166, 41), (124, 106), (198, 73), (164, 42), (169, 40), (195, 39), (156, 122), (197, 56), (173, 165), (104, 66), (116, 69), (168, 145), (193, 118), (95, 70), (127, 110), (119, 100), (180, 100), (195, 45), (115, 95), (191, 98), (106, 84), (110, 89), (184, 34)]
# ...
